# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BSBI/VisualizationTableau/Visualization')

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
duplicate_count = df['EmployeeNumber'].duplicated().sum()
print(f"Number of duplicate values in 'Employee Number': {duplicate_count}")
# Out:
# Number of duplicate values in 'Employee Number': 0
